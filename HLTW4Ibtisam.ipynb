# %%
import pandas as pd
df=pd.read_csv("destination.csv")
df.shape
# Out:
# (14, 5)

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
print(df.iloc[2:8])
# Out:
#             Destination   Feedback  Average Hotel Star Rating  \
# 2                Tunisia         6                          2
# 3                  India         3                          1
# 4              Australia         1                          1
# 5               Thailand         9                          4
# 6  �United Arab Emirates         7                          3
# 7                �Jordan         5                          4
#
#    Inclusive Hotels Offer Most Visited City
# 2                     101              Sousse
# 3                     230              Mumbai
# 4                      80              Sydney
# 5                     117             Bangkok
# 6                     349               Dubai
# 7                       4               Amman

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
print(df.loc[[]])
# Out:
# Empty DataFrame
# Columns: [Destination , Feedback, Average Hotel Star Rating, Inclusive Hotels Offer, Most Visited City  ]
# Index: []

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
df["Inclusive Hotels Offer"].mean()
# Out:
# 169.5

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
df["Feedback"].max()
# Out:
# 10

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
df["Feedback"].min()
# Out:
# 1

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
f_filter =df["Inclusive Hotels Offer"]>9

f_filter
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# Name: Inclusive Hotels Offer, dtype: bool

# %%
import pandas as pd
df=pd.read_csv("destination.csv")
above8=df["Feedback"]>8
above8
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# Name: Feedback, dtype: bool

# %%
print(df,)
lower2=df["Feedback"]<2
lower2
# Out:
#              Destination   Feedback  Average Hotel Star Rating  \
# 0                 Morocco         6                          4
# 1              Cape Verde         8                          5
# 2                 Tunisia         6                          2
# 3                   India         3                          1
# 4               Australia         1                          1
# 5                Thailand         9                          4
# 6   �United Arab Emirates         7                          3
# 7                 �Jordan         5                          4
# 8               Mauritius        10                          5
# 9                   �Cuba         2                          2
# 10                 Mexico         9                          1
# 11                  Egypt         5                          3
# 12               Malaysia        10                          5
# 13                  Qatar         8                          5
#
#     Inclusive Hotels Offer Most Visited City
# 0                       45           Marrakesh
# 1                        8          Sao Filipe
# 2                      101              Sousse
# 3                      230              Mumbai
# 4                       80              Sydney
# 5                      117             Bangkok
# 6                      349               Dubai
# 7                        4               Amman
# 8                       25          Port Louis
# 9                        7              Havana
# 10                     398         Mexico City
# 11                     204               Cairo
# 12                     550        Kuala Lupmur
# 13                     255                Doha
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: Feedback, dtype: bool

# %%
import pandas as pd
df=pd.read_csv("destination.csv")

from sklearn.datasets import load_iris

data=load_iris
df=pd.read_csv("destination.csv")
df.head(15)
# Out:
#              Destination   Feedback  Average Hotel Star Rating  \
# 0                 Morocco         6                          4
# 1              Cape Verde         8                          5
# 2                 Tunisia         6                          2
# 3                   India         3                          1
# 4               Australia         1                          1
# 5                Thailand         9                          4
# 6   �United Arab Emirates         7                          3
# 7                 �Jordan         5                          4
# 8               Mauritius        10                          5
# 9                   �Cuba         2                          2
# 10                 Mexico         9                          1
# 11                  Egypt         5                          3
# 12               Malaysia        10                          5
# 13                  Qatar         8                          5
#
#     Inclusive Hotels Offer Most Visited City
# 0                       45           Marrakesh
# 1                        8          Sao Filipe
# 2                      101              Sousse
# 3                      230              Mumbai
# 4                       80              Sydney
# 5                      117             Bangkok
# 6                      349               Dubai
# 7                        4               Amman
# 8                       25          Port Louis
# 9                        7              Havana
# 10                     398         Mexico City
# 11                     204               Cairo
# 12                     550        Kuala Lupmur
# 13                     255                Doha

# %%
df.plot(4)
# Out:
# <AxesSubplot:xlabel='Most Visited City  '>

# %%
df.plot.scatter(x="Inclusive Hotels Offer", y="Feedback")
# Out:
# <AxesSubplot:xlabel='Inclusive Hotels Offer', ylabel='Feedback'>

# %%
columns= ["Inclusive Hotels Offer", "Most Visited City  ", "Feedback"]
df[columns].plot.area()
# Out:
# <AxesSubplot:>

# %%
df.groupby("Destination ").mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Destination '>
